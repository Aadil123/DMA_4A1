# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
train_data = pd.read_csv("FinalDataSet_final_1_2.csv",encoding = 'utf-8')
test_data = pd.read_csv("testing_dataset.csv",encoding = 'utf-8')

# %%
train_data
# Out:
#                Date               Commodity         Variety    Grade  \
# 0        01/01/2010                   Bajra          Hybrid  Average
# 1        01/01/2010                   Bajra          Hybrid  Average
# 2        01/01/2010                   Bajra          Hybrid  Average
# 3        01/01/2010                   Bajra          Hybrid  Average
# 4        01/01/2010                   Bajra          Hybrid    Small
# 5        01/01/2010                   Bajra          Hybrid   Medium
# 6        01/01/2010                   Bajra          Hybrid  Average
# 7        01/01/2010                   Bajra           Local  Average
# 8        01/01/2010                   Bajra           Local  Average
# 9        01/01/2010                   Bajra           Local  Average
# 10       01/01/2010                   Jowar  Jowar ( White)  Average
# 11       01/01/2010                   Jowar  Jowar ( White)  Average
# 12       01/01/2010                   Jowar  Jowar ( White)  Average
# 13       01/01/2010                   Jowar  Jowar ( White)  Average
# 14       01/01/2010                   Jowar  Jowar ( White)  Average
# 15       01/01/2010                   Jowar  Jowar ( White)  Average
# 16       01/01/2010                   Jowar  Jowar ( White)  Average
# 17       01/01/2010                   Jowar  Jowar ( White)  Average
# 18       01/01/2010                   Jowar  Jowar ( White)  Average
# 19       01/01/2010                   Jowar  Jowar (Yellow)  Average
# 20       01/01/2010                   Jowar           Local  Average
# 21       01/01/2010                   Jowar    Jowar Hybrid      FAQ
# 22       01/01/2010                   Jowar    Jowar Hybrid  Average
# 23       01/01/2010                   Jowar          Hybrid  Average
# 24       01/01/2010                   Jowar          Hybrid  Average
# 25       01/01/2010                   Maize    Hybrid/Local  Average
# 26       01/01/2010                   Maize    Hybrid/Local   Medium
# 27       01/01/2010                   Maize    Hybrid/Local  Average
# 28       01/01/2010                   Maize    Hybrid/Local      FAQ
# 29       01/01/2010                   Maize    Hybrid/Local  Average
# ...             ...                     ...             ...      ...
# 1006773  31/12/2016          Tamarind Fruit  Tamarind Fruit  Average
# 1006774  31/12/2016          Tamarind Fruit  Tamarind Fruit  Average
# 1006775  31/12/2016          Tamarind Fruit  Tamarind Fruit  Average
# 1006776  31/12/2016          Tamarind Fruit  Tamarind Fruit  Average
# 1006777  31/12/2016           Tamarind Seed   Tamarind Seed  Average
# 1006778  31/12/2016         Bull (For Each)            Bull  Average
# 1006779  31/12/2016         Bull (For Each)            Bull  Average
# 1006780  31/12/2016          Cow (For Each)             Cow  Average
# 1006781  31/12/2016          Cow (For Each)             Cow  Average
# 1006782  31/12/2016          Cow (For Each)             Cow  Average
# 1006783  31/12/2016         Goat (For Each)            Goat  Average
# 1006784  31/12/2016         Goat (For Each)            Goat   Medium
# 1006785  31/12/2016         Goat (For Each)            Goat  Average
# 1006786  31/12/2016         Goat (For Each)            Goat  Average
# 1006787  31/12/2016   He Baffalo (For Each)      He Baffelo  Average
# 1006788  31/12/2016           Ox (For Each)              Ox   Medium
# 1006789  31/12/2016           Ox (For Each)              Ox  Average
# 1006790  31/12/2016           Ox (For Each)              Ox  Average
# 1006800             Flowers
# 1006801             Flowers
# 1006802             Flowers
#
# [1006803 rows x 11 columns]

# %% [markdown]
# ## Usman

# %%
train_data.shape
# Out:
# (1006803, 11)

# %%
test_data.shape
# Out:
# (51221, 10)

# %%
test_data.head()
# Out:
#          Date Commodity         Variety    Grade                Market  \
# 0  01/01/2017     Bajra          Hybrid  Average               KUSTAGI
# 1  01/01/2017     Jowar  Jowar ( White)  Average              BELAGAVI
# 2  01/01/2017     Jowar  Jowar ( White)   Medium  HAGARI BOMMANA HALLI
# 3  01/01/2017     Jowar    Jowar Hybrid  Average              HUMNABAD
# 4  01/01/2017     Maize           Local  Average              SHIGGAON
#
#    Arrival      Unit   Min   Max  Modal
# 0      150  Quintal�  1510  1510   1510
# 1       10  Quintal�  2800  3400   3200
# 2       25  Quintal�  1630  1630   1630
# 3       29  Quintal�  1000  1100   1050
# 4     2913  Quintal�  1300  1400   1362

# %%
pd.unique(test_data['Unit'].values.ravel())
# Out:
# array(['Quintal�', 'Numbers�', 'Thousands', 'Quintal', 'Numbers'], dtype=object)

# %%
pd.unique(test_data['Commodity'].values.ravel())
# Out:
# array(['Bajra', 'Jowar', 'Maize', 'Navane', 'Paddy', 'Ragi', 'Rice',
#        'Blackgram', 'Cowpea', 'Greengram', 'Horse Gram', 'Tur', 'Copra',
#        'Groundnut', 'Groundnut Seed', 'Soyabeen', 'Sunflower', 'Cotton',
#        'Jute', 'Beans', 'Beetroot', 'Bitter Gourd', 'Bottle Gourd',
#        'Brinjal', 'Cabbage', 'Capsicum', 'Carrot', 'Cauliflower',
#        'Chilly Capsicum', 'Cucumbar', 'Green Chilly', 'Green Ginger',
#        'Knool Khol', 'Onion', 'Potato', 'Raddish', 'Ridgeguard',
#        'Seemebadanekai', 'Snakeguard', 'Sweet Potato', 'Sweet Pumpkin',
#        'Tomato', 'Coriander Seed', 'Coconut (Per 1000)', 'Jaggery',
#        'Tender Coconut', 'Arecanut', 'Cow (For Each)', 'Goat (For Each)',
#        'Ox (For Each)', 'She Baffalo (For Each)', 'She Goat (For Each)',
#        'Sheep (For Each)', 'Same/Savi', 'Wheat', 'Alasande Gram', 'Arhar',
#        'Avare', 'Avaredal', 'Bengal Gramdal', 'Bengalgram',
#        'Black Gramdal', 'Chennangidal', 'Green Gramdal', 'Tur Dal',
#        'Castor Seed', 'Gingelly', 'Mustard', 'Neem Seed', 'Safflower',
#        'Sesamum', 'Apple', 'Banana', 'Borehannu', 'Chikoos (Sapota)',
#        'Grapes', 'Karbuja', 'Mousambi', 'Orange', 'Papaya', 'Pine Apple',
#        'Pomagranate', 'Water Melon', 'Alasandikai', 'Ash Gourd',
#        'Banana Green', 'Bunch Beans', 'Chapparada Avare', 'Coriander',
#        'Drum Stick', 'Green Avare (W)', 'Ladies Finger',
#        'Leafy Vegetables', 'Lime (Lemon)', 'Peas Wet', 'Suvarnagadde',
#        'Thogarikai', 'Thondekai', 'White Pumpkin', 'Dry Chillies',
#        'Garlic', 'Ginger', 'Pepper', 'Turmeric', 'Cashewnut',
#        'Coco Brooms', 'Betal Leaves', 'Soapnut', 'Tamarind Fruit',
#        'Tamarind Seed', 'Sajje', 'Green Peas', 'Lint�', 'Ram (For Each)',
#        'Chilly Red', 'Methi Seeds', 'Dry Grapes', 'Maragenasu',
#        'Bull (For Each)', 'Calf (For Each)', 'He Baffalo (For Each)',
#        'Crysanthamum', 'Marygold', 'Rose', 'Honge Seed', 'Moath',
#        'Gurellu', 'Marasebu', 'Citrus Fruit', 'Mataki', 'Barley',
#        'Jack Fruit', 'Sweet Lime', 'Redgram', 'Cotton Seed', 'Cumminseed',
#        'All Flowers', 'Lint', 'Mango (Raw-Ripe)', 'Soji', 'Duster Beans',
#        'T. V. Cumbu', 'Antawala', 'Mango', 'Wood', 'Skin and Hide'], dtype=object)

# %% [markdown]
# # Our training data and testing data have certain unclean values in some of the columns
# # So we need to clean the values in those columns

# %%
print("Cleaning training data...")
train_data = train_data.replace({'Quintal�':'Quintal'}, regex = True)
train_data = train_data.replace({'Quintal ':'Quintal'}, regex = True)
train_data = train_data.replace({'Numbers�':'Numbers'}, regex = True)
train_data = train_data.replace({'Numbers ':'Numbers'}, regex = True)
train_data = train_data.replace({'Lint�':'Lint'}, regex = True)
train_data = train_data.replace({'Lint ':'Lint'}, regex = True)
train_data = train_data.replace({'Sona Masuri Old�':'Sona Masuri Old'}, regex = True)
print("Cleaning training data...completed")
print("Cleaning testing data...")
test_data = test_data.replace({'Quintal�':'Quintal'}, regex = True)
test_data = test_data.replace({'Quintal ':'Quintal'}, regex = True)
test_data = test_data.replace({'Numbers�':'Numbers'}, regex = True)
test_data = test_data.replace({'Numbers ':'Numbers'}, regex = True)
test_data = test_data.replace({'Lint�':'Lint'}, regex = True)
test_data = test_data.replace({'Lint ':'Lint'}, regex = True)
test_data = test_data.replace({'Sona Masuri Old�':'Sona Masuri Old'}, regex = True)
print("Cleaning testing data...completed")
# Out:
# Cleaning training data...
# Cleaning training data...completed
# Cleaning testing data...
# Cleaning testing data...completed

# %%
pd.unique(test_data['Unit'].values.ravel())
# Out:
# array(['Quintal', 'Numbers', 'Thousands'], dtype=object)

# %% [markdown]
# ## Akshay

# %% [markdown]
# #### Let's check the amount of null values present in the training data

# %%
train_data.isnull().sum()
# Out:
# Date            0
# Commodity       0
# Variety         0
# Grade           0
# Market          0
# Arrival         0
# Unit            0
# Min             0
# Max             0
# Modal           0
# Group        9828
# dtype: int64

# %% [markdown]
# #### We can easily infer that only the group column has null values. This may be due to erroneous entries in the dataset. We need to fix it. This can be done by assigning to the null values, its preceding value

# %%
train_data.fillna(method='ffill',inplace = True)
train_data.isnull().sum()
# Out:
# Date         0
# Commodity    0
# Variety      0
# Grade        0
# Market       0
# Arrival      0
# Unit         0
# Min          0
# Max          0
# Modal        0
# Group        0
# dtype: int64

# %% [markdown]
# ### The null values have been replaced

# %% [markdown]
# ## Importing test dataset

# %%
test_data.head()
# Out:
#          Date Commodity         Variety    Grade                Market  \
# 0  01/01/2017     Bajra          Hybrid  Average               KUSTAGI
# 1  01/01/2017     Jowar  Jowar ( White)  Average              BELAGAVI
# 2  01/01/2017     Jowar  Jowar ( White)   Medium  HAGARI BOMMANA HALLI
# 3  01/01/2017     Jowar    Jowar Hybrid  Average              HUMNABAD
# 4  01/01/2017     Maize           Local  Average              SHIGGAON
#
#    Arrival     Unit   Min   Max  Modal
# 0      150  Quintal  1510  1510   1510
# 1       10  Quintal  2800  3400   3200
# 2       25  Quintal  1630  1630   1630
# 3       29  Quintal  1000  1100   1050
# 4     2913  Quintal  1300  1400   1362

# %% [markdown]
# ## Aadil

# %% [markdown]
# ## In the test dataset, the Group column is empty
# ## We need to fill it with appropriate values

# %%
dictionary = dict(zip(train_data.Commodity, train_data.Group))
dictionary
# Out:
# {'Alasande Gram': 'Pulses',
#  'Alasandikai': 'Vegetables',
#  'All Flowers': 'Live Stock/Poultry',
#  'Antawala': 'Forest Products',
#  'Apple': 'Fruits',
#  'Arecanut': 'Drugs & Narcotics',
#  'Arhar': 'Pulses',
#  'Ash Gourd': 'Vegetables',
#  'Avare': 'Pulses',
#  'Avaredal': 'Pulses',
#  'Bajra': 'Cereals',
#  'Banana': 'Fruits',
#  'Banana Green': 'Vegetables',
#  'Beans': 'Vegetables',
#  'Beetroot': 'Vegetables',
#  'Bengal Gramdal': 'Pulses',
#  'Bengalgram': 'Pulses',
#  'Betal Leaves': 'Drugs & Narcotics',
#  'Bitter Gourd': 'Vegetables',
#  'Black Gramdal': 'Pulses',
#  'Blackgram': 'Pulses',
#  'Borehannu': 'Fruits',
#  'Bottle Gourd': 'Vegetables',
#  'Brinjal': 'Vegetables',
#  'Bull (For Each)': 'Live Stock/Poultry',
#  'Bullar': 'Pulses',
#  'Bunch Beans': 'Vegetables',
#  'Cabbage': 'Vegetables',
#  'Calf (For Each)': 'Live Stock/Poultry',
#  'Capsicum': 'Vegetables',
#  'Carrot': 'Vegetables',
#  'Cashewnut': 'Dry Fruits',
#  'Castor Seed': 'Oil Seeds',
#  'Cauliflower': 'Vegetables',
#  'Chapparada Avare': 'Vegetables',
#  'Chennangidal': 'Pulses',
#  'Chikoos (Sapota)': 'Fruits',
#  'Chilly Capsicum': 'Vegetables',
#  'Chilly Red': 'Vegetables',
#  'Citrus Fruit': 'Dry Fruits',
#  'Coco Brooms': 'Other',
#  'Coconut (Per 1000)': 'Other',
#  'Copra': 'Oil Seeds',
#  'Coriander': 'Vegetables',
#  'Coriander Seed': 'Spices',
#  'Cotton': 'Fibre Crops',
#  'Cotton Seed': 'Oil Seeds',
#  'Cow (For Each)': 'Live Stock/Poultry',
#  'Cowpea': 'Pulses',
#  'Cowpea (Veg)': 'Vegetables',
#  'Crysanthamum': 'Flowers',
#  'Cucumbar': 'Vegetables',
#  'Drum Stick': 'Vegetables',
#  'Dry Chillies': 'Spices',
#  'Dry Grapes': 'Dry Fruits',
#  'Duster Beans': 'Vegetables',
#  'Garlic': 'Spices',
#  'Gingelly': 'Oil Seeds',
#  'Ginger': 'Spices',
#  'Goat (For Each)': 'Live Stock/Poultry',
#  'Grapes': 'Fruits',
#  'Green Avare (W)': 'Vegetables',
#  'Green Chilly': 'Vegetables',
#  'Green Ginger': 'Vegetables',
#  'Green Gramdal': 'Pulses',
#  'Green Peas': 'Pulses',
#  'Greengram': 'Pulses',
#  'Groundnut': 'Oil Seeds',
#  'Groundnut Seed': 'Oil Seeds',
#  'Guava': 'Fruits',
#  'Gurellu': 'Oil Seeds',
#  'He Baffalo (For Each)': 'Live Stock/Poultry',
#  'Hippe Seed': 'Oil Seeds',
#  'Honge Seed': 'Oil Seeds',
#  'Horse Gram': 'Pulses',
#  'Jack Fruit': 'Fruits',
#  'Jaggery': 'Other',
#  'Jowar': 'Cereals',
#  'Karbuja': 'Fruits',
#  'Knool Khol': 'Vegetables',
#  'Ladies Finger': 'Vegetables',
#  'Leafy Vegetables': 'Vegetables',
#  'Lime (Lemon)': 'Vegetables',
#  'Linseed': 'Oil Seeds',
#  'Lint': 'Fibre Crops',
#  'Maize': 'Cereals',
#  'Mango': 'Fruits',
#  'Mango (Raw-Ripe)': 'Vegetables',
#  'Maragenasu': 'Vegetables',
#  'Marasebu': 'Fruits',
#  'Marygold': 'Flowers',
#  'Mataki': 'Pulses',
#  'Methi Seeds': 'Spices',
#  'Moath': 'Pulses',
#  'Mousambi': 'Fruits',
#  'Mustard': 'Oil Seeds',
#  'Navane': 'Cereals',
#  'Neem Seed': 'Oil Seeds',
#  'Niger Seed': 'Oil Seeds',
#  'Onion': 'Vegetables',
#  'Orange': 'Fruits',
#  'Ox (For Each)': 'Live Stock/Poultry',
#  'Paddy': 'Cereals',
#  'Papaya': 'Fruits',
#  'Peas Wet': 'Vegetables',
#  'Pepper': 'Spices',
#  'Pine Apple': 'Fruits',
#  'Pomagranate': 'Fruits',
#  'Potato': 'Vegetables',
#  'Raddish': 'Vegetables',
#  'Ragi': 'Cereals',
#  'Ram (For Each)': 'Live Stock/Poultry',
#  'Redgram': 'Pulses',
#  'Rice': 'Cereals',
#  'Ridgeguard': 'Vegetables',
#  'Rose': 'Flowers',
#  'Safflower': 'Oil Seeds',
#  'Sajje': 'Cereals',
#  'Same/Savi': 'Cereals',
#  'Seemebadanekai': 'Vegetables',
#  'Seethaphal': 'Fruits',
#  'Sesamum': 'Oil Seeds',
#  'She Baffalo (For Each)': 'Live Stock/Poultry',
#  'She Goat (For Each)': 'Live Stock/Poultry',
#  'Sheep (For Each)': 'Live Stock/Poultry',
#  'Snakeguard': 'Vegetables',
#  'Soapnut': 'Forest Products',
#  'Soji': 'Cereals',
#  'Soyabeen': 'Oil Seeds',
#  'Sunflower': 'Oil Seeds',
#  'Suvarnagadde': 'Vegetables',
#  'Sweet Lime': 'Fruits',
#  'Sweet Potato': 'Vegetables',
#  'Sweet Pumpkin': 'Vegetables',
#  'T. V. Cumbu': 'Cereals',
#  'Tamarind Fruit': 'Forest Products',
#  'Tamarind Seed': 'Forest Products',
#  'Tender Coconut': 'Other',
#  'Thogarikai': 'Vegetables',
#  'Thondekai': 'Vegetables',
#  'Tomato': 'Vegetables',
#  'Tur': 'Pulses',
#  'Tur Dal': 'Pulses',
#  'Turmeric': 'Spices',
#  'Water Melon': 'Fruits',
#  'Wheat': 'Cereals',
#  'White Pumpkin': 'Vegetables',
#  'Wood': 'Forest Products'}

# %%
test_data['Group'] = test_data['Commodity'].map(dictionary)
test_data.head()
# Out:
#          Date Commodity         Variety    Grade                Market  \
# 0  01/01/2017     Bajra          Hybrid  Average               KUSTAGI
# 1  01/01/2017     Jowar  Jowar ( White)  Average              BELAGAVI
# 2  01/01/2017     Jowar  Jowar ( White)   Medium  HAGARI BOMMANA HALLI
# 3  01/01/2017     Jowar    Jowar Hybrid  Average              HUMNABAD
# 4  01/01/2017     Maize           Local  Average              SHIGGAON
#
#    Arrival     Unit   Min   Max  Modal    Group
# 0      150  Quintal  1510  1510   1510  Cereals
# 1       10  Quintal  2800  3400   3200  Cereals
# 2       25  Quintal  1630  1630   1630  Cereals
# 3       29  Quintal  1000  1100   1050  Cereals
# 4     2913  Quintal  1300  1400   1362  Cereals

# %% [markdown]
# ## Aravind

# %% [markdown]
# ### Now we concatenate the training and testing data

# %%
data = pd.concat((train_data, test_data), axis=0, ignore_index=True)
data.shape
# Out:
# (1058024, 11)

# %%
data
# Out:
#                Date               Commodity         Variety    Grade  \
# 0        01/01/2010                   Bajra          Hybrid  Average
# 1        01/01/2010                   Bajra          Hybrid  Average
# 2        01/01/2010                   Bajra          Hybrid  Average
# 3        01/01/2010                   Bajra          Hybrid  Average
# 4        01/01/2010                   Bajra          Hybrid    Small
# 5        01/01/2010                   Bajra          Hybrid   Medium
# 6        01/01/2010                   Bajra          Hybrid  Average
# 7        01/01/2010                   Bajra           Local  Average
# 8        01/01/2010                   Bajra           Local  Average
# 9        01/01/2010                   Bajra           Local  Average
# 10       01/01/2010                   Jowar  Jowar ( White)  Average
# 11       01/01/2010                   Jowar  Jowar ( White)  Average
# 12       01/01/2010                   Jowar  Jowar ( White)  Average
# 13       01/01/2010                   Jowar  Jowar ( White)  Average
# 14       01/01/2010                   Jowar  Jowar ( White)  Average
# 15       01/01/2010                   Jowar  Jowar ( White)  Average
# 16       01/01/2010                   Jowar  Jowar ( White)  Average
# 17       01/01/2010                   Jowar  Jowar ( White)  Average
# 18       01/01/2010                   Jowar  Jowar ( White)  Average
# 19       01/01/2010                   Jowar  Jowar (Yellow)  Average
# 20       01/01/2010                   Jowar           Local  Average
# 21       01/01/2010                   Jowar    Jowar Hybrid      FAQ
# 22       01/01/2010                   Jowar    Jowar Hybrid  Average
# 23       01/01/2010                   Jowar          Hybrid  Average
# 24       01/01/2010                   Jowar          Hybrid  Average
# 25       01/01/2010                   Maize    Hybrid/Local  Average
# 26       01/01/2010                   Maize    Hybrid/Local   Medium
# 27       01/01/2010                   Maize    Hybrid/Local  Average
# 28       01/01/2010                   Maize    Hybrid/Local      FAQ
# 28                  Cereals
# 29                  Cereals
# ...                     ...
# 1057994     Forest Products
# 1057995     Forest Products
# 1057996     Forest Products
# 1057997     Forest Products
# 1057998     Forest Products
# 1057999  Live Stock/Poultry
# 1058000  Live Stock/Poultry
# 1058001  Live Stock/Poultry
# 1058002  Live Stock/Poultry
# 1058003  Live Stock/Poultry
# 1058004  Live Stock/Poultry
# 1058005  Live Stock/Poultry
# 1058006  Live Stock/Poultry
# 1058007  Live Stock/Poultry
# 1058008  Live Stock/Poultry
# 1058009  Live Stock/Poultry
# 1058010  Live Stock/Poultry
# 1058011  Live Stock/Poultry
# 1058012  Live Stock/Poultry
# 1058013  Live Stock/Poultry
# 1058014  Live Stock/Poultry
# 1058015  Live Stock/Poultry
# 1058016  Live Stock/Poultry
# 1058017  Live Stock/Poultry
# 1058018  Live Stock/Poultry
# 1058019  Live Stock/Poultry
# 1058020  Live Stock/Poultry
# 1058021             Flowers
# 1058022             Flowers
# 1058023             Flowers
#
# [1058024 rows x 11 columns]

# %% [markdown]
# ### In the Units column of data, there are three distinct values:

# %%
pd.unique(data['Unit'].values.ravel())
# Out:
# array(['Quintal', 'Numbers', 'Thousands'], dtype=object)

# %% [markdown]
# ### We can reduce it to 2 by converting Thosands into Numbers. This will facilitate in easier analysis

# %%
data['Arrival'] = np.where(data['Unit']=='Thousands',data['Arrival'],data['Arrival'])
data = data.replace({'Thousands':'Numbers'}, regex = True)

# %%
pd.unique(data['Unit'].values.ravel())
# Out:
# array(['Quintal', 'Numbers'], dtype=object)

# %% [markdown]
# ### Let us check if the data still has null values

# %%
data.isnull().sum()
# Out:
# Date          0
# Commodity     0
# Variety       0
# Grade         0
# Market        0
# Arrival       0
# Unit          0
# Min           0
# Max           0
# Modal         0
# Group        64
# dtype: int64

# %% [markdown]
# ### We can follow the same procedure as above to replace the null values

# %%
data.fillna(method='ffill',inplace = True)
data.isnull().sum()
# Out:
# Date         0
# Commodity    0
# Variety      0
# Grade        0
# Market       0
# Arrival      0
# Unit         0
# Min          0
# Max          0
# Modal        0
# Group        0
# dtype: int64

# %% [markdown]
# ### We are adding one more column 'Avg' which holds the average of Min and Max column values

# %%
data['Avg'] = (data['Min']+data['Max'])/2.0
data
# Out:
#                Date               Commodity         Variety    Grade  \
# 0        01/01/2010                   Bajra          Hybrid  Average
# 1        01/01/2010                   Bajra          Hybrid  Average
# 2        01/01/2010                   Bajra          Hybrid  Average
# 3        01/01/2010                   Bajra          Hybrid  Average
# 4        01/01/2010                   Bajra          Hybrid    Small
# 5        01/01/2010                   Bajra          Hybrid   Medium
# 6        01/01/2010                   Bajra          Hybrid  Average
# 7        01/01/2010                   Bajra           Local  Average
# 8        01/01/2010                   Bajra           Local  Average
# 9        01/01/2010                   Bajra           Local  Average
# 10       01/01/2010                   Jowar  Jowar ( White)  Average
# 11       01/01/2010                   Jowar  Jowar ( White)  Average
# 12       01/01/2010                   Jowar  Jowar ( White)  Average
# 13       01/01/2010                   Jowar  Jowar ( White)  Average
# 1058019         BADAMI      285  Numbers   3200   6700   5200
# 1058020         BADAMI     1120  Numbers   2800   6900   4800
# 1058021  CHICKBALLAPUR       18  Quintal  10000  12000  10500
# 1058022  CHICKBALLAPUR       53  Quintal   1000   2500   1500
# 1058023  CHICKBALLAPUR       45  Quintal   1500   3500   2200
#
#                       Group      Avg
# 0                   Cereals   2100.0
# 1                   Cereals   1377.0
# 2                   Cereals   1402.5
# 3                   Cereals   1325.0
# 4                   Cereals   1375.0
# 5                   Cereals   1378.0
# 6                   Cereals   2721.0
# 7                   Cereals   1461.5
# 8                   Cereals   1425.0
# 9                   Cereals   1472.0
# 10                  Cereals   2200.0
# 11                  Cereals   1530.0
# 12                  Cereals   2500.0
# 13                  Cereals   1462.5
# 14                  Cereals   2050.0
# 15                  Cereals   2830.0
# 16                  Cereals   1640.0
# 17                  Cereals   1473.5
# 18                  Cereals   3250.0
# 19                  Cereals   2212.5
# 20                  Cereals   1850.0
# 21                  Cereals   1381.5
# 22                  Cereals   1273.0
# 23                  Cereals   1775.0
# 24                  Cereals   1290.0
# 25                  Cereals   1525.0
# 26                  Cereals   1325.0
# 27                  Cereals   1360.0
# 28                  Cereals   1360.0
# 29                  Cereals   1425.0
# ...                     ...      ...
# 1057994     Forest Products   4150.0
# 1057995     Forest Products   6652.0
# 1057996     Forest Products   1515.0
# 1057997     Forest Products   1525.0
# 1057998     Forest Products   1420.0
# 1057999  Live Stock/Poultry  46500.0
# 1058000  Live Stock/Poultry  20000.0
# 1058001  Live Stock/Poultry  22000.0
# 1058002  Live Stock/Poultry   6500.0
# 1058003  Live Stock/Poultry  42500.0
# 1058004  Live Stock/Poultry  31500.0
# 1058005  Live Stock/Poultry  30000.0
# 1058006  Live Stock/Poultry  39500.0
# 1058007  Live Stock/Poultry   3400.0
# 1058008  Live Stock/Poultry   7150.0
# 1058009  Live Stock/Poultry   3500.0
# 1058010  Live Stock/Poultry  49250.0
# 1058011  Live Stock/Poultry  67500.0
# 1058012  Live Stock/Poultry  20000.0
# 1058013  Live Stock/Poultry  23000.0
# 1058014  Live Stock/Poultry   7050.0
# 1058015  Live Stock/Poultry  31500.0
# 1058016  Live Stock/Poultry  50000.0
# 1058017  Live Stock/Poultry  30000.0
# 1058018  Live Stock/Poultry  38000.0
# 1058019  Live Stock/Poultry   4950.0
# 1058020  Live Stock/Poultry   4850.0
# 1058021             Flowers  11000.0
# 1058022             Flowers   1750.0
# 1058023             Flowers   2500.0
#
# [1058024 rows x 12 columns]

# %% [markdown]
# ## Usman

# %%
data.Group.value_counts(dropna=True).plot(kind="bar",color="red",rot=0)

# %%
veg=data.loc[data['Group']=='Vegetables','Commodity']

# %%
veg.value_counts(dropna=True).plot(kind="bar",color="blue",rot=0)

# %% [markdown]
# ## Aadil

# %%
veg.value_counts(dropna=True).plot(kind="line",color="blue",rot=0)

# %%
data.Modal.value_counts(dropna=True).plot(kind="bar",color="Blue",position=0,label = "Modal",rot=0)
data.Avg.value_counts(dropna=True).plot(kind="bar",color="Green",position =1,label = "Average",rot=0)


plt.legend()
plt.xlabel('Prices')
plt.ylabel('Count')

sns.despine()
plt.show()

# %%
veg_avg = data.loc[data['Group'] == 'Vegetables', 'Avg'].value_counts()
veg_modal = data.loc[data['Group'] == 'Vegetables', 'Modal'].value_counts()


# Bar width
width = 0.4

veg_avg.iloc[0:10].plot(kind='bar', width=width, color='skyblue', position=0, label='Average Price', rot=0)
veg_modal.iloc[0:10].plot(kind='bar', width=width, color='orange', position=1, label='Modal Price', rot=0)

plt.legend()
plt.xlabel('Price')
plt.ylabel('Count')

sns.despine()
plt.show()

# %% [markdown]
# ### The algorithms available for classification are:
#    #### 1. C4.5
#    #### 2. k-nearest neighbour classifier
#    #### 3. Naive Bayes
#    #### 4. Support Vector Machine (SVM)
#    #### 5. Apriori
#    #### 6. AdaBoost
#    #### 7. Random Forest
#    #### 8. Decision tree

# %% [markdown]
# ### The algorithms available for regression are:
# #### 1. Decision tree
# #### 2. Random Forest
# #### 3. Time-series
# #### 4. Linear regression
# #### 5. Generalised Linear Model

# %% [markdown]
# ### We have studied Decision tree and Random forest because our predictions involve both classification and regression. These two algorithms handle both classification and regression problems.

# %%
X_train = train_data.drop("Arrival",axis = 1,inplace = False)
X_train = train_data.drop("Group",axis = 1,inplace = False)
Y_train = train_data["Arrival"]
X_test = test_data.drop("Arrival",axis =1,inplace = False)
X_test = test_data.drop("Group",axis =1,inplace = False)
Y_test = test_data["Arrival"]

# %% [markdown]
# #### Arrival attribute is to be predicted, so it is removed from training and testing data and put into X variable
# #### Hence arrival attribute is to be put into Y variable

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
# Iterating over all the common columns in train and test
for col in X_test.columns.values:
       # Encoding only categorical variables
       if X_test[col].dtypes=='object':
               data=X_train[col].append(X_test[col])
               le.fit(data.values)
               X_train[col]=le.transform(X_train[col])
               X_test[col]=le.transform(X_test[col])

# %% [markdown]
# ### Encoding methods available:
# #### Ordinal
# #### One-Hot
# #### Label
# #### Helmert Contrast
# #### Sum Contrast
# #### Polynomial Contrast
# #### Backward Difference Contrast
# #### Simple Hashing

# %% [markdown]
# ### We have used one-hot encoding and label encoding because one hot encoding yields faster algorithms and label encoding helps in running linear regression faster

# %% [markdown]
# #### Label encoding is done so that the regression methods accept categorical data
# #### For example, our data has Commodity attribute which has values like Wheat, Jowar, Maize, Paddy etc.
# #### What label encoding does is it assigns to each record in an attribute, an integer number like Wheat=0, Jowar=1, Maize=2, Paddy=3 etc.

# %%
X_train = X_train[:10000]
X_test = X_test[:10000]
Y_train = Y_train[:10000]
Y_test = Y_test[:10000]
X_train
X_test
# Out:
#       Date  Commodity  Variety  Grade  Market  Arrival  Unit   Min   Max  \
# 0        7         10      126      0      88      150     1  1510  1510
# 1        7         79      145      0      13       10     1  2800  3400
# 2        7         79      145      3      45       25     1  1630  1630
# 3        7         79      147      0      65       29     1  1000  1100
# 4        7         88      165      0     125     2913     1  1300  1400
# 5        7         88      165      0       1      400     1  1200  1250
# 6        7         88      165      0     114        8     1  1303  1339
# 7        7         88      165      0      73     3499     1  1380  1410
# 8        7         88      127      0      88      100     1  1425  1425
# 9        7         88      165      3      79      240     1  1350  1450
# 10       7         88      127      3      45     7078     1  1370  1450
# 11       7         88      303      0      43      100     1  1500  1600
# 12       7         88      127      0      24      200     1  1400  1400
# 13       7         88      165      0      55      455     1  1350  1520
# 14       7         88      127      0      15      300     1  1320  1320
# 15       7         99      191      0      88      100     1  1550  1550
# 16       7        105      221      3      45     1279     1  1600  1950
# 17       7        105      210      0      91       82     1  1600  1600
# 18       7        105      210      3      66     1473     1  1900  1930
# 19       7        113      165      0      43       95     1  2000  3000
# 20       7        116      143      0      80        9     1  2000  2000
# 21       7         21       32      0      55        1     1  5000  5000
# 22       7         21       32      0      65       12     1  5000  6100
# 23       7         49       74      0      88       50     1  7010  7010
# 24       7         68      104      0      65       53     1  4000  4400
# 25       7         76      123      0      43       35     1  3000  3500
# 26       7         76      123      0      88       20     1  3250  3250
# 27       7        145      294      0     123      300     1  4400  4700
# 28       7        145      294      0      65      202     1  4500  4800
# 29       7         43       66      0      43      198     1  6000  6500
# ...    ...        ...      ...    ...     ...      ...   ...   ...   ...
# 9970  1178         63      101      0      50        2     1  2500  2500
# 9971  1178         64      102      0      21      140     1  2000  4200
# 9972  1178         64      102      0      36        3     1  2000  3000
# 9973  1178         64      102      0      33       45     1  2000  2800
# 9974  1178         64      102      3      56       25     1   800   900
# 9975  1178         64      102      0      50       10     1  1200  1200
# 9976  1178         64      102      0      61       38     1  1100  1500
# 9977  1178         64      102      0       7        6     1  1000  1600
# 9978  1178         64      102      0     113       10     1  4000  4400
# 9979  1178         64      102      0      78       18     1  2000  2500
# 9980  1178         64      102      0      28       11     1  2000  3800
# 9981  1178         64      102      0     127       27     1  2200  2400
# 9982  1178         64      102      0     103       72     1  3300  3500
# 9983  1178         64      102      0      29       70     1  1685  1885
# 9984  1178         65      103      0      16       97     1  1500  2200
# 9985  1178         65      103      0      21      210     1  2200  2500
# 9986  1178         65      103      0      78        7     1  1300  1500
# 9987  1178         65      103      3     126      240     1  1000  1100
# 9988  1178         65      103      0     103       18     1  1800  2000
# 9989  1178         65      103      0     105      300     1  1000  1000
# 9990  1178         65      103      0      50    38163     1  1000  1798
# 9991  1178         65      103      0      15     1400     1  1000  1200
# 9992  1178         65      103      0     146        1     1  1800  2000
# 9993  1178         65      103      0      52       40     1  1000  1000
# 9994  1178         65      103      0      61       20     1  1200  1800
# 9995  1178         65      103      0       1       60     1  1200  1200
# 9996  1178         65      103      0     120     1347     1   950  1150
# 9997  1178         65      103      0     110      318     1  1000  1200
# 9998  1178         65      103      0     141      290     1   800  1000
# 9999  1178         65      103      0      99      143     1  1000  1000
#
#       Modal
# 0      1510
# 1      3200
# 2      1630
# 3      1050
# 4      1362
# 5      1200
# 6      1313
# 7      1400
# 8      1425
# 9      1400
# 10     1420
# 11     1500
# 12     1400
# 13     1350
# 14     1320
# 15     1550
# 16     1900
# 17     1600
# 18     1920
# 19     2500
# 20     2000
# 21     5000
# 22     6000
# 23     7010
# 24     4200
# 25     3000
# 26     3250
# 27     4600
# 28     4600
# 29     6500
# ...     ...
# 9970   2500
# 9971   2500
# 9972   2500
# 9973   2400
# 9974    850
# 9975   1200
# 9976   1300
# 9977   1450
# 9978   4200
# 9979   2300
# 9980   3000
# 9981   2300
# 9982   3400
# 9983   1785
# 9984   1850
# 9985   2300
# 9986   1400
# 9987   1050
# 9988   1900
# 9989   1000
# 9990   1200
# 9991   1000
# 9992   1900
# 9993   1000
# 9994   1600
# 9995   1200
# 9996   1000
# 9997   1100
# 9998    924
# 9999   1000
#
# [10000 rows x 10 columns]

# %% [markdown]
# #### We have considered the first 10000 records of the data because the first 10000 records consist of all the data needed for preprocessing

# %%
from sklearn.preprocessing import scale
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.formula.api as smf
from sklearn.metrics import accuracy_score
X_train_scale=scale(X_train)
X_test_scale=scale(X_test)
# Fitting the linear regression model
lm = linear_model.LinearRegression()
model = lm.fit(X_train_scale,Y_train)
predictions = lm.predict(X_test)
# Checking the models accuracy
lm.score(X_test,Y_test)
# Out:
# -511458706.09907115

# %% [markdown]
# ### One hot encoding is done so that all the categorical variables are converted into a suitable format for use in the models

# %%
from sklearn.preprocessing import OneHotEncoder
enc=OneHotEncoder(sparse=False)
X_train_1=X_train
X_test_1=X_test
columns=['Commodity', 'Variety', 'Grade', 'Unit']
for col in columns:
       # creating an exhaustive list of all possible categorical values
       data=X_train[[col]].append(X_test[[col]])
       enc.fit(data)
       # Fitting One Hot Encoding on train data
       temp = enc.transform(X_train[[col]])
       # Changing the encoded features into a data frame with new column names
       temp=pd.DataFrame(temp,columns=[(col+"_"+str(i)) for i in data[col].value_counts().index])
       # In side by side concatenation index values should be same
       # Setting the index values similar to the X_train data frame
       temp=temp.set_index(X_train.index.values)
       # adding the new One Hot Encoded varibales to the train data frame
       X_train_1=pd.concat([X_train_1,temp],axis=1)
       # fitting One Hot Encoding on test data
       temp = enc.transform(X_test[[col]])
       # changing it into data frame and adding column names
       temp=pd.DataFrame(temp,columns=[(col+"_"+str(i)) for i in data[col]
            .value_counts().index])
       # Setting the index for proper concatenation
       temp=temp.set_index(X_test.index.values)
       # adding the new One Hot Encoded varibales to test data frame
       X_test_1=pd.concat([X_test_1,temp],axis=1)

# %% [markdown]
# #### One hot encoding is better that Label encoding because it assigns onlt 2 unique values 0,1 to the data. This helps in analyzing the data quickly.
# #### Label encoding was used for linear regression earlier because one hot encoding creates extra attributes which will slow down the performance of linear regression
# #### However, algorithm like Random forest performs faster with one hot encoded data
# #### The attributes 'Commodity', 'Variety', 'Grade', 'Unit' are categorical. Hence these must be one hot encoded

# %% [markdown]
# ### Random forest

# %%
X_train_1 = X_train[:10000]
X_test_1 = X_test[:10000]
Y_train_1 = Y_train[:10000]
Y_test_1 = Y_test[:10000]
#Import Library
from sklearn.ensemble import RandomForestRegressor 
# Create Random Forest object
model= RandomForestRegressor()
# Train the model using the training sets and check score
model.fit(X_train_1, Y_train_1)
#Predict Output
prediction= model.predict(X_test_1)

# %%
prediction
# Out:
# array([ 150. ,   10. ,   25. , ...,  318. ,  289.8,  143. ])

# %%
from sklearn.metrics import explained_variance_score
explained_variance_score(Y_test, prediction)
# Out:
# 0.89547605181852274

# %% [markdown]
# #### We got a variance score of 0.8954

# %% [markdown]
# #### The variance score is calculated because the more the variance score, the more variant is our data.
# #### More variant data means that the algorithms have more diverse attributes and hence yield better performance.

# %%
from sklearn.metrics import r2_score
r2_score(Y_test, prediction)
# Out:
# 0.89546993112482398

# %% [markdown]
# #### Random forest is used because it overcomes the problem of overfitting
# #### Random Forest does not depend on whether the problem is of classififcation or of regression

# %%
from sklearn.metrics import median_absolute_error
model_mse = median_absolute_error(Y_test,prediction)
print(model_mse)
# Out:
# 0.0

# %% [markdown]
# ### Gradient Boosting Model(GBM)

# %%
from sklearn.ensemble import GradientBoostingClassifier #For Classification
from sklearn.ensemble import GradientBoostingRegressor 

#use GBM function

clf = GradientBoostingRegressor(n_estimators=1000, learning_rate=1.0, max_depth=1)
pred =clf.fit(X_train_1, Y_train_1)

# %% [markdown]
# ### When we did not use GBM, we got a variance score of 0.574. This showed that the predictive performance of the model was low. When GBM was used, the score increased to 0.9119. This shows that our data was overfitted

# %% [markdown]
# ### We have used Gradient boosting because we want to avoid over fitting in our data. GBM algorithm reduces overfitting and hence it is been used.

# %%
r2_score(Y_test_1, pred)
# Out:
# 0.91194066166321797

# %%
explained_variance_score(Y_test, pred)
# Out:
# 0.91194873411014976

# %% [markdown]
# #### We got a variance score of 0.9119 after applying the Gradient boosting algorithm

# %% [markdown]
# #### Gradient boosting has been used to boost the performance of the algorithm
# #### Gradient boosting helps in overcoming overfitting by reducing it

# %%
from sklearn.metrics import median_absolute_error
model_mse = median_absolute_error(Y_test,pred)
print(model_mse)
# Out:
# 11.9665512127

# %% [markdown]
# ### Decision tree

# %%
from sklearn import tree
X = train_data.drop("Arrival",axis = 1,inplace = False)
y = train_data["Arrival"]
x_test = test_data.drop("Arrival",axis = 1,inplace = False)
X= X[:10000]
y= y[:10000]
x_test = x_test[:10000]
# Create tree object 
model = tree.DecisionTreeRegressor()  
# Train the model using the training sets and check score
model.fit(X_train_1, Y_train_1)
model.score(X_train_1, Y_train_1)
#Predict Output
predicted= model.predict(X_test_1)

# %%
predicted
# Out:
# array([ 150.,   10.,   25., ...,  318.,  289.,  143.])

# %%
accuracy_score(predicted, Y_test)
# Out:
# 0.82750000000000001

# %% [markdown]
# #### Decision trees are independent of the type of problem i.e., classification or regression
# #### Here, data type is not a constraint
# #### As our data involves both clasification and regression methods, decision tree is considered

# %%
from sklearn.metrics import median_absolute_error
model_mse = median_absolute_error(Y_test,predicted)
print(model_mse)
# Out:
# 0.0

# %% [markdown]
# #### We have chosen Random forest over decision tree because decision tree builds only a single tree, whereas random forest builds many trees and chooses the best tree among them
# #### This ensures better results
# #### Also, as our data has both classification (predicting variety that is most popular in an area) and regression (predicting the commodity with highest arrival quantity at a market) problems, Random forest can be used efficiently for both the purposes
